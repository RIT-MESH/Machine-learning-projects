# %%
import numpy as np # numerical python

# %%
from PIL import Image # Python Image Library
import matplotlib # 
import cv2

# %%
from matplotlib import image

# %%
from matplotlib import image

img = image.imread('data/test.jpg')

# %%
# !pip install pillow # install PIL
# Out:
# Collecting pillow
#   Downloading https://files.pythonhosted.org/packages/44/4b/78226761e8ce14686fa7fa834c357d5b0a933d7485955b716fab3071f7e5/Pillow-7.0.0-cp36-cp36m-win_amd64.whl (2.0MB)
# Installing collected packages: pillow
# Successfully installed pillow-7.0.0
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# Reading image using PIL
img = Image.open('./data/test.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x1200 at 0x5E279F4B20>

# %%
# loading using matplotlib : (RBG)
img_mat = matplotlib.image.imread("./data/test.jpg")
img_mat
# Out:
# array([[[98, 52, 26],
#         [94, 48, 22],
#         [89, 43, 17],
#         ...,
#         [11, 12,  0],
#         [13, 14,  0],
#         [14, 15,  1]],
#
#        [[95, 49, 23],
#         [94, 48, 22],
#         [91, 45, 19],
#         ...,
#         [12, 13,  0],
#         [14, 15,  1],
#         [15, 16,  2]],
#
#        [[91, 45, 19],
#         [93, 47, 21],
#         [93, 47, 21],
#         ...,
#         [13, 14,  0],
#         [14, 15,  1],
#         [15, 16,  2]],
#
#        ...,
#
#        [[96, 66, 40],
#         [93, 63, 37],
#         [91, 61, 35],
#         ...,
#         [73, 94,  0],
#         [76, 97,  2],
#         [76, 97,  2]],
#
#        [[94, 64, 38],
#         [91, 61, 35],
#         [91, 61, 35],
#         ...,
#         [70, 91,  0],
#         [74, 95,  0],
#         [74, 95,  0]],
#
#        [[91, 61, 35],
#         [90, 60, 34],
#         [92, 62, 36],
#         ...,
#         [70, 91,  0],
#         [76, 97,  2],
#         [75, 96,  1]]], dtype=uint8)

# %%
# read image using opencv : BGR (Blue Green and Red)
img_cv = cv2.imread('./data/test.jpg')
img_cv
# Out:
# array([[[26, 52, 98],
#         [22, 48, 94],
#         [17, 43, 89],
#         ...,
#         [ 0, 12, 11],
#         [ 0, 14, 13],
#         [ 1, 15, 14]],
#
#        [[23, 49, 95],
#         [22, 48, 94],
#         [19, 45, 91],
#         ...,
#         [ 0, 13, 12],
#         [ 1, 15, 14],
#         [ 2, 16, 15]],
#
#        [[19, 45, 91],
#         [21, 47, 93],
#         [21, 47, 93],
#         ...,
#         [ 0, 14, 13],
#         [ 1, 15, 14],
#         [ 2, 16, 15]],
#
#        ...,
#
#        [[40, 66, 96],
#         [37, 63, 93],
#         [35, 61, 91],
#         ...,
#         [ 0, 94, 73],
#         [ 2, 97, 76],
#         [ 2, 97, 76]],
#
#        [[38, 64, 94],
#         [35, 61, 91],
#         [35, 61, 91],
#         ...,
#         [ 0, 91, 70],
#         [ 0, 95, 74],
#         [ 0, 95, 74]],
#
#        [[35, 61, 91],
#         [34, 60, 90],
#         [36, 62, 92],
#         ...,
#         [ 0, 91, 70],
#         [ 2, 97, 76],
#         [ 1, 96, 75]]], dtype=uint8)

# %%
# displaying images
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(img_mat) # rgb

# %%
plt.imshow(img_cv)

# %%
img_mat.shape
# Out:
# (1200, 1600, 3)

# %%
# analyzing image by matplotlib
# split array into three parts
r = img_mat[:,:,0] # red array
g = img_mat[:,:,1] # green array
b = img_mat[:,:,2] # blue array

# %%
r.shape,g.shape,b.shape
# Out:
# ((1200, 1600), (1200, 1600), (1200, 1600))

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,3,1) #subplot(row,column,image number)
plt.title('Red region')
plt.imshow(r,cmap='gray')
plt.subplot(1,3,2)
plt.title('Green region')
plt.imshow(g,cmap='gray')
plt.subplot(1,3,3)
plt.title('Blue region')
plt.imshow(b,cmap='gray')
plt.show()

# %%
# gray scale : 2d 
gray_MAT = cv2.cvtColor(img_mat,cv2.COLOR_RGB2GRAY)

# %%
# gray scale : 2d 
gray_CV = cv2.cvtColor(img_cv,cv2.COLOR_BGR2GRAY)

# %%
gray_MAT.shape, gray_CV.shape
# Out:
# ((1200, 1600), (1200, 1600))

# %%
plt.imshow(gray_MAT,cmap='gray')

# %%
plt.imshow(gray_CV,cmap='gray')

# %%
gray_CV
# Out:
# array([[63, 59, 54, ..., 10, 12, 13],
#        [60, 59, 56, ..., 11, 13, 14],
#        [56, 58, 58, ..., 12, 13, 14],
#        ...,
#        [72, 69, 67, ..., 77, 80, 80],
#        [70, 67, 67, ..., 74, 78, 78],
#        [67, 66, 68, ..., 74, 80, 79]], dtype=uint8)
